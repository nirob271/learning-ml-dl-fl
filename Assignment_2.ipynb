# %% [markdown]
# <a href="https://colab.research.google.com/github/nirob271/learning-ml-dl-fl/blob/main/Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Create variables for your name, age, and favorite color, then print them with descriptive labels.

# %%
name = "Saiful Islam Nirob"
age = 21
favorite_color = "Blue"
print("Name :",name)
print("Age :",age)
print("Favorite Color :",favorite_color)
# Out:
# Name :  Saiful Islam Nirob
# Age :  21
# Favorite Color :  Blue

# %% [markdown]
# 2. Create one variable of each type and use the type() function to verify its type.

# %%
name = "Nirob"
age = 21
height = 5.6
num = 1j
ok = True
x = None
a = ["Nirob" , "Mission" , "Rimon"]
b = ("Nirob" , "Mission" , "Rimon")
c = {
    "name" : "Nirob",
    "age" : "21",
    "university" : "Prime University"
}

print(type(name))
print(type(age))
print(type(height))
print(type(num))
print(type(ok))
print(type(x))
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'bool'>
# <class 'NoneType'>
# <class 'list'>
# <class 'tuple'>
# <class 'dict'>

# %% [markdown]
# 3. Calculate the area and perimeter of a rectangle with length 7 and width 5.

# %%
length = 7
width = 5
area = length * width
print("Area of a rectangle ", area)
# Out:
# Area of a rectangle  35

# %% [markdown]
# 4. Create a list of 5 Bangladeshi foods, then access the first and last elements.

# %%
list = ["Kacchi Biryani" , "Shorshe Ilish" , "Fuchka" , " Morog Polao" , "Beef Kala Bhuna"]
x = list[0]
y = list[4]
print(x)
print(y)
# Out:
# Kacchi Biryani
# Beef Kala Bhuna

# %% [markdown]
# 5. Create a list of 5 numbers, add a new number, remove one, and then sort the list.

# %%
list = [3,2,1,5,4]
list.append(6)
list.remove(1)
list.sort()
print(list)
# Out:
# [2, 3, 4, 5, 6]

# %% [markdown]
# 6. Create a dictionary about yourself with at least 4 key-value pairs.

# %%
dic = {
    "Name" : "Saiful Islam Nirob",
    "Age" : 21,
    "University" : "Prime University",
    "Programme" : "Bsc in CSE"
}
print(dic)
# Out:
# {'Name': 'Saiful Islam Nirob', 'Age': 21, 'University': 'Prime University', 'Programme': 'Bsc in CSE'}

# %% [markdown]
# 7. Create a tuple with the latitude and longitude of a famous place in Bangladesh.

# %%
Coxs_bazar = (21.26, 91.59)
print("Cox's Bazar Beach:", Coxs_bazar)
# Out:
# Cox's Bazar Beach: (21.26, 91.59)

# %% [markdown]
# 8. Create two sets of colors and find their union and intersection.

# %%
s1 = {"Red" , "Blue" , "Green"}
s2 = {"White" , "Black" , "Green" , "Purple"}
res1 = s1 | s2
res2 = s1 & s2
print(res1)
print(res2)
# Out:
# {'Green', 'Black', 'Red', 'Purple', 'Blue', 'White'}
# {'Green'}

# %% [markdown]
# 9. Write a Python function that takes a string as input and prints the first and last character of the string.

# %%
def solve(s):
  print(s[0])
  print(s[-1])

name = input("Enter a String: ");
solve(name)
# Out:
# Enter a String: AKif
# A
# f

# %% [markdown]
# 10. Write a Python function that takes a string and converts it to uppercase.

# %%
def solve(s):
  print(s.upper())

name = input("Enter text: ")
solve(name)
# Out:
# Enter text: Nirob
# NIROB
